# %% [markdown]
# <a href="https://colab.research.google.com/github/Harini0324/AGRICART-/blob/main/top50_PopularityBased.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random

# %%
df=pd.read_csv('/content/csv')

# %%
def generate_farmer_name(used_names):
    first_names = ['John', 'Jane', 'Michael', 'Emily', 'David', 'Sarah', 'Daniel', 'Olivia', 'James', 'Sophia','Ramesh','Suresh','Mala','Kala','Ramya','Angel']
    last_names = ['Smith', 'Johnson', 'Williams', 'Jones', 'Brown', 'Davis', 'Miller', 'Wilson', 'Moore', 'Taylor']

    while True:
        name = f"{random.choice(first_names)} {random.choice(last_names)}"
        if name not in used_names:
            return name

# Create a list of 200 unique random farmer names
num_names = 100
used_names = set()
farmer_names = []

for _ in range(num_names):
    name = generate_farmer_name(used_names)
    farmer_names.append(name)
    used_names.add(name)

# Create a DataFrame
#df = pd.DataFrame({'farmer_name': farmer_names})

# Save the DataFrame to a CSV file
#df.to_csv('unique_farmer_names.csv', index=False)

# %%
def generate_phone_number():
    return str(random.randint(9000000000, 9999999999))

df['phone_number'] = [generate_phone_number() for _ in range(len(df))]

# %%
def generate_farmer_name1():
    return random.choice(farmer_names)

df['farmer_name'] = [generate_farmer_name1() for _ in range(len(df))]

# %%
df.to_csv('updated_csv', index=False)

# %%
df=pd.read_csv('/content/updated_csv')

# %% [markdown]
# # ## POPULARITY BASED : TOP 50

# %%
num_df=df.groupby('commodity').count()['modal_price'].reset_index()
num_df.rename(columns={'modal_price':'sold count'},inplace=True)
num_df
# Out:
#                      commodity  sold count
# 0                   Amaranthus           9
# 1              Amla(Nelli Kai)           1
# 2                  Amphophalus           6
# 3                        Apple          32
# 4    Arecanut(Betelnut/Supari)           9
# ..                         ...         ...
# 151                Water Melon           5
# 152                      Wheat          45
# 153                 Wheat Atta           3
# 154              White Pumpkin           1
# 155                       Wood           7
#
# [156 rows x 2 columns]

# %%
avg_df=df.groupby('commodity').mean()['modal_price'].reset_index()
avg_df.rename(columns={'modal_price':'avg_price'},inplace=True)
avg_df
# Out:
# <ipython-input-5-42ec5705663f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_df=df.groupby('commodity').mean()['modal_price'].reset_index()
#                      commodity     avg_price
# 0                   Amaranthus   2916.666667
# 1              Amla(Nelli Kai)   3800.000000
# 2                  Amphophalus   2450.000000
# 3                        Apple   5722.968750
# 4    Arecanut(Betelnut/Supari)  15827.777778
# ..                         ...           ...
# 151                Water Melon   1260.000000
# 152                      Wheat   1913.400000
# 153                 Wheat Atta   2866.666667
# 154              White Pumpkin    310.000000
# 155                       Wood    377.857143
#
# [156 rows x 2 columns]

# %%
popular_df=num_df.merge(avg_df , on='commodity')
popular_df
# Out:
#                      commodity  sold count     avg_price
# 0                   Amaranthus           9   2916.666667
# 1              Amla(Nelli Kai)           1   3800.000000
# 2                  Amphophalus           6   2450.000000
# 3                        Apple          32   5722.968750
# 4    Arecanut(Betelnut/Supari)           9  15827.777778
# ..                         ...         ...           ...
# 151                Water Melon           5   1260.000000
# 152                      Wheat          45   1913.400000
# 153                 Wheat Atta           3   2866.666667
# 154              White Pumpkin           1    310.000000
# 155                       Wood           7    377.857143
#
# [156 rows x 3 columns]

# %%
popular_df = popular_df[ popular_df ['sold count']>15].sort_values('sold count',ascending=False).head(50)
popular_df
# Out:
#                          commodity  sold count    avg_price
# 118                         Potato         113   762.309735
# 147                         Tomato         103  1143.601942
# 101                          Onion          99  1082.333333
# 105            Paddy(Dhan)(Common)          99  1685.323232
# 24                         Brinjal          99  1374.989899
# 31                     Cauliflower          83  1185.421687
# 9                           Banana          74  2543.581081
# 61                    Green Chilli          74  2831.351351
# 26                         Cabbage          69  1016.449275
# 28                          Carrot          69  1169.130435
# 123                           Rice          53  2827.641509
# 120                        Raddish          50   496.660000
# 45                Cucumbar(Kheera)          45  2520.555556
# 152                          Wheat          45  1913.400000
# 18           Bhindi(Ladies Finger)          43  3638.255814
# ...

# %%
popular_df.merge(df,on='commodity')
# Out:
#      commodity  sold count    avg_price                state  \
# 0       Potato         113   762.309735  Andaman and Nicobar
# 1       Potato         113   762.309735                Assam
# 2       Potato         113   762.309735                Assam
# 3       Potato         113   762.309735                Assam
# 4       Potato         113   762.309735              Gujarat
# ...        ...         ...          ...                  ...
# 1682    Kinnow          16  1440.625000               Punjab
# 1683    Kinnow          16  1440.625000               Punjab
# 1684    Kinnow          16  1440.625000               Punjab
# 1685    Kinnow          16  1440.625000        Uttar Pradesh
# 1686    Kinnow          16  1440.625000           Uttrakhand
#
#                       district             market  variety arrival_date  \
# 0                South Andaman         Port Blair    Other   04/03/2019
# 1                      Darrang         Kharupetia  Badshah   04/03/2019
# ...

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))
